# %% [markdown]
# # Checkpoint Three: Cleaning Data
#
# Now you are ready to clean your data. Before starting coding, provide the link to your dataset below.
#
# My dataset: https://www.kaggle.com/datasets/catherinerasgaitis/mxmh-survey-results
#
# Import the necessary libraries and create your dataframe(s).

# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

df = pd.read_csv("mxmh_survey_results copy.csv")

#i'm importing the same libraries from checkpoint 2 to do my work here
#i also made a copy of my original csv file to add to the new checkpoint folder to work on

# %%
pd.set_option('display.max_columns', None)
df.head(11)

#I'm using this code here in a seperate cell so that I am able to quickly look back and forth at my dataset and reference the information as needed
#this code in particular will allow me to see all columns of my data at once instead of a limited view
# Out:
#              Timestamp   Age          Primary streaming service  \
# 0   8/27/2022 19:29:02  18.0                            Spotify
# 1   8/27/2022 19:57:31  63.0                            Pandora
# 2   8/27/2022 21:28:18  18.0                            Spotify
# 3   8/27/2022 21:40:40  61.0                      YouTube Music
# 4   8/27/2022 21:54:47  18.0                            Spotify
# 5   8/27/2022 21:56:50  18.0                            Spotify
# 6   8/27/2022 22:00:29  18.0                      YouTube Music
# 7   8/27/2022 22:18:59  21.0                            Spotify
# 8   8/27/2022 22:33:05  19.0                            Spotify
# 9   8/27/2022 22:44:03  18.0  I do not use a streaming service.
# 10  8/27/2022 22:51:15  18.0                            Spotify
#
#     Hours per day While working Instrumentalist Composer         Fav genre  \
# 0             3.0           Yes             Yes      Yes             Latin
# 1             1.5           Yes              No       No              Rock
# 2             4.0            No              No       No  Video game music
# 3             2.5           Yes              No      Yes              Jazz
# 4             4.0           Yes              No       No               R&B
# 5             5.0           Yes             Yes      Yes              Jazz
# 6             3.0           Yes             Yes       No  Video game music
# 7             1.0           Yes              No       No             K pop
# 8             6.0           Yes              No       No              Rock
# 9             1.0           Yes              No       No               R&B
# 10            3.0           Yes             Yes       No           Country
#
#    Exploratory Foreign languages    BPM Frequency [Classical]  \
# 0          Yes               Yes  156.0                Rarely
# 1          Yes                No  119.0             Sometimes
# 2           No               Yes  132.0                 Never
# 3          Yes               Yes   84.0             Sometimes
# 4          Yes                No  107.0                 Never
# 5          Yes               Yes   86.0                Rarely
# 6          Yes               Yes   66.0             Sometimes
# 7          Yes               Yes   95.0                 Never
# 8           No                No   94.0                 Never
# 9          Yes               Yes  155.0                Rarely
# 10         Yes                No    NaN                 Never
#
#    Frequency [Country]  Frequency [EDM] Frequency [Folk] Frequency [Gospel]  \
# 0                Never           Rarely            Never              Never
# 1                Never            Never           Rarely          Sometimes
# 2                Never  Very frequently            Never              Never
# 3                Never            Never           Rarely          Sometimes
# 4                Never           Rarely            Never             Rarely
# 5            Sometimes            Never            Never              Never
# 6                Never           Rarely        Sometimes             Rarely
# 7                Never           Rarely            Never              Never
# 8      Very frequently            Never        Sometimes              Never
# 9               Rarely           Rarely           Rarely          Sometimes
# 10     Very frequently            Never            Never              Never
#
#    Frequency [Hip hop] Frequency [Jazz] Frequency [K pop] Frequency [Latin]  \
# 0            Sometimes            Never   Very frequently   Very frequently
# 1               Rarely  Very frequently            Rarely         Sometimes
# 2               Rarely           Rarely   Very frequently             Never
# 3                Never  Very frequently         Sometimes   Very frequently
# 4      Very frequently            Never   Very frequently         Sometimes
# 5            Sometimes  Very frequently   Very frequently            Rarely
# 6               Rarely        Sometimes             Never            Rarely
# 7      Very frequently           Rarely   Very frequently             Never
# 8                Never            Never             Never             Never
# 9               Rarely           Rarely             Never            Rarely
# 10               Never            Never             Never             Never
#
#    Frequency [Lofi] Frequency [Metal]  Frequency [Pop]  Frequency [R&B]  \
# 0            Rarely             Never  Very frequently        Sometimes
# 1            Rarely             Never        Sometimes        Sometimes
# 2         Sometimes         Sometimes           Rarely            Never
# 3         Sometimes             Never        Sometimes        Sometimes
# 4         Sometimes             Never        Sometimes  Very frequently
# 5   Very frequently            Rarely  Very frequently  Very frequently
# 6            Rarely            Rarely           Rarely           Rarely
# 7         Sometimes             Never        Sometimes        Sometimes
# 8             Never   Very frequently            Never            Never
# 9            Rarely             Never        Sometimes        Sometimes
# 10            Never             Never           Rarely           Rarely
#
#     Frequency [Rap] Frequency [Rock] Frequency [Video game music]  Anxiety  \
# 0   Very frequently            Never                    Sometimes      3.0
# 1            Rarely  Very frequently                       Rarely      7.0
# 2            Rarely           Rarely              Very frequently      7.0
# 3             Never            Never                        Never      9.0
# 4   Very frequently            Never                       Rarely      7.0
# 5   Very frequently  Very frequently                        Never      8.0
# 6             Never            Never                    Sometimes      4.0
# 7            Rarely            Never                       Rarely      5.0
# 8             Never  Very frequently                        Never      2.0
# 9            Rarely        Sometimes                    Sometimes      2.0
# 10            Never           Rarely                        Never      7.0
#
#     Depression  Insomnia  OCD Music effects    Permissions
# 0          0.0       1.0  0.0           NaN  I understand.
# 1          2.0       2.0  1.0           NaN  I understand.
# 2          7.0      10.0  2.0     No effect  I understand.
# 3          7.0       3.0  3.0       Improve  I understand.
# 4          2.0       5.0  9.0       Improve  I understand.
# 5          8.0       7.0  7.0       Improve  I understand.
# 6          8.0       6.0  0.0       Improve  I understand.
# 7          3.0       5.0  3.0       Improve  I understand.
# 8          0.0       0.0  0.0       Improve  I understand.
# 9          2.0       5.0  1.0       Improve  I understand.
# 10         7.0       4.0  7.0     No effect  I understand.

# %% [markdown]
# ## Missing Data
#
# Test your dataset for missing data and handle it as needed. Make notes in the form of code comments as to your thought process.

# %%
df.shape 
#736 rows, 33 columns, making a basic note here as a reminder of how much data I am working with
# Out:
# (736, 33)

# %%
df.duplicated().value_counts() 
#There are no duplicates in the data to remove
# Out:
# False    736
# dtype: int64

# %%
df.isnull().sum() 

#BPM column has most null values (107) however since this column is based on survey info that was optional for the responder to fill, it still holds important info for later use
#The music effects column has 8 null values, however I don't believe that it will negatively effect the outcome of the analysis since it is such a small amount  
#The other columns that have missing data are the age, primary streaming service, while working, instrumentalist, composer, and foreign language columns
#These columns all have < 5 null values in total which I do not believe will require them to be discarde
# Out:
# Timestamp                         0
# Age                               1
# Primary streaming service         1
# Hours per day                     0
# While working                     3
# Instrumentalist                   4
# Composer                          1
# Fav genre                         0
# Exploratory                       0
# Foreign languages                 4
# BPM                             107
# Frequency [Classical]             0
# Frequency [Country]               0
# Frequency [EDM]                   0
# Frequency [Folk]                  0
# Frequency [Gospel]                0
# Frequency [Hip hop]               0
# Frequency [Jazz]                  0
# Frequency [K pop]                 0
# Frequency [Latin]                 0
# Frequency [Lofi]                  0
# Frequency [Metal]                 0
# Frequency [Pop]                   0
# Frequency [R&B]                   0
# Frequency [Rap]                   0
# Frequency [Rock]                  0
# Frequency [Video game music]      0
# Anxiety                           0
# Depression                        0
# Insomnia                          0
# OCD                               0
# Music effects                     8
# Permissions                       0
# dtype: int64

# %% [markdown]
# ## Irregular Data
#
# Detect outliers in your dataset and handle them as needed. Use code comments to make notes about your thought process.

# %%
df['Hours per day'].describe()
#I want to find out if there is any data that might skew the amount of hours that certain music genres are listened to 
#based on the output, there is an outlier where the max amount of hours listened is 24 hours, which is unusual since people often listen to music in sessions and not for the entire day
# Out:
# count    736.000000
# mean       3.572758
# std        3.028199
# min        0.000000
# 25%        2.000000
# 50%        3.000000
# 75%        5.000000
# max       24.000000
# Name: Hours per day, dtype: float64

# %%
#I am going to make a scatter plot to vizualize the outlier and see how many are present in the data 
df.head(740).plot(x= 'Age', y= 'Hours per day', kind = 'scatter')
#Based on the chart output, there are two outliers in which a respondent listened to music for 20-25 hours straight, which will effect the result when trying to answer
#the question of which music genres are listened to the most
#one of the respondents was at age 90, so it is highly possible there was an input error on their survey
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Hours per day'>

# %%
#I am going to run a code that orders the data by the 'hours per day' column with the largest hour amounts at the top to see what genres are associated with these numbers
df.sort_values(by=['Hours per day'], ascending=False).head()
#based on the output, the rock and rap genres are the two that have the outlier hour amount compared to the rest of the survery results, which will need to be 
#considered when answering the question of which music genres are most popular amongst users since it could be interpreted that the highlt listening volume correlates 
#to how popular a music genre is
# Out:
#                Timestamp   Age Primary streaming service  Hours per day  \
# 366   8/29/2022 12:32:30  16.0                   Spotify           24.0
# 695   9/28/2022 17:25:48  89.0                   Spotify           24.0
# 18    8/27/2022 23:40:55  17.0                   Spotify           24.0
# 290    8/29/2022 2:46:27  27.0                   Spotify           20.0
# 726  10/23/2022 20:50:27  18.0               Apple Music           18.0
#
#     While working Instrumentalist Composer Fav genre Exploratory  \
# 366           Yes              No       No      Rock         Yes
# 695           Yes             Yes      Yes       Rap          No
# 18            Yes              No       No       Rap         Yes
# 290           Yes              No       No      Rock         Yes
# 726           Yes              No       No       EDM         Yes
#
#     Foreign languages    BPM Frequency [Classical] Frequency [Country]  \
# 366               Yes  120.0                 Never               Never
# 695                No  143.0                 Never               Never
# 18                 No   99.0                Rarely               Never
# 290               Yes    NaN             Sometimes              Rarely
# 726                No   90.0             Sometimes              Rarely
#
#      Frequency [EDM] Frequency [Folk] Frequency [Gospel] Frequency [Hip hop]  \
# 366           Rarely            Never              Never               Never
# 695           Rarely           Rarely              Never     Very frequently
# 18             Never            Never              Never           Sometimes
# 290        Sometimes           Rarely              Never              Rarely
# 726  Very frequently            Never             Rarely           Sometimes
#
#     Frequency [Jazz] Frequency [K pop] Frequency [Latin] Frequency [Lofi]  \
# 366            Never            Rarely            Rarely           Rarely
# 695        Sometimes             Never             Never           Rarely
# 18         Sometimes         Sometimes            Rarely            Never
# 290            Never         Sometimes            Rarely        Sometimes
# 726        Sometimes             Never             Never        Sometimes
#
#     Frequency [Metal] Frequency [Pop] Frequency [R&B]  Frequency [Rap]  \
# 366            Rarely          Rarely          Rarely           Rarely
# 695            Rarely          Rarely       Sometimes  Very frequently
# 18          Sometimes          Rarely       Sometimes  Very frequently
# 290   Very frequently          Rarely           Never           Rarely
# 726         Sometimes          Rarely       Sometimes        Sometimes
#
#     Frequency [Rock] Frequency [Video game music]  Anxiety  Depression  \
# 366        Sometimes                       Rarely      5.0         1.0
# 695           Rarely                        Never      0.0         0.0
# 18   Very frequently                        Never      7.0         5.0
# 290  Very frequently                    Sometimes      8.0        10.0
# 726        Sometimes                    Sometimes      9.0         8.0
#
#      Insomnia   OCD Music effects    Permissions
# 366       9.0   1.0       Improve  I understand.
# 695       0.0   0.0     No effect  I understand.
# 18        0.0   3.0       Improve  I understand.
# 290      10.0   8.0     No effect  I understand.
# 726       5.0  10.0       Improve  I understand.

# %%
#the previous visualization can also be used when looking at the age distribution of the survey respondents
#I wanted to see if there were any ages that were outliers that might skew data on which age ranges would msot likely watch and interact with a product ad
#when answering a question regarding what age range is most most marketed towards for a specific ad (which is one of my business questions)
#the results of the graph are also important at it shows which age ranges will be most likely to engage in future electronic surveys and be present when watching these ads
#to give potential feedback or engage with a product

# %%
#since the data does have 4 other columns with numerical data (outside of the BPM since it has so may null values) I will also use a scatterplot to 
#detect if there are any outliers here
#while the data is in a scale range, I want to make sure that no respondents put info outside of the 1-10 range that might skew the data
#I've run the scatterplot through each mental health condition and found no outliers
df.head(300).plot(x= 'Depression', y= 'Hours per day', kind = 'scatter')
# Out:
# <AxesSubplot:xlabel='Depression', ylabel='Hours per day'>

# %% [markdown]
# ## Unnecessary Data
#
# Look for the different types of unnecessary data in your dataset and address it as needed. Make sure to use code comments to illustrate your thought process.

# %%
df['Permissions'].unique()
# Out:
# array(['I understand.'], dtype=object)

# %%
df['Permissions'].value_counts()
#I am considering removing the permissions table and I wanted to check for any unique values in case a responder chose against giving consent for their info to be used 
#it looks like all of the responders gave consent for their results to be used, for now I will keep the column although since the data is all under the same permission grant this column may be removed in the future
# Out:
# I understand.    736
# Name: Permissions, dtype: int64

# %%
df.drop(['Timestamp'], axis=1)
#I am going to remove the 'Timestamp' column since the information here is not relevant to the analysis
# Out:
#       Age Primary streaming service  Hours per day While working  \
# 0    18.0                   Spotify            3.0           Yes
# 1    63.0                   Pandora            1.5           Yes
# 2    18.0                   Spotify            4.0            No
# 3    61.0             YouTube Music            2.5           Yes
# 4    18.0                   Spotify            4.0           Yes
# ..    ...                       ...            ...           ...
# 731  17.0                   Spotify            2.0           Yes
# 732  18.0                   Spotify            1.0           Yes
# 733  19.0   Other streaming service            6.0           Yes
# 734  19.0                   Spotify            5.0           Yes
# 735  29.0             YouTube Music            2.0           Yes
#
#     Instrumentalist Composer         Fav genre Exploratory Foreign languages  \
# 0               Yes      Yes             Latin         Yes               Yes
# 1                No       No              Rock         Yes                No
# 2                No       No  Video game music          No               Yes
# 3                No      Yes              Jazz         Yes               Yes
# 4                No       No               R&B         Yes                No
# ..              ...      ...               ...         ...               ...
# 731             Yes       No              Rock         Yes               Yes
# 732             Yes       No               Pop         Yes               Yes
# 733              No      Yes               Rap         Yes                No
# 734             Yes       No         Classical          No                No
# 735              No       No           Hip hop         Yes               Yes
#
#        BPM Frequency [Classical] Frequency [Country]  Frequency [EDM]  \
# 0    156.0                Rarely               Never           Rarely
# 1    119.0             Sometimes               Never            Never
# 2    132.0                 Never               Never  Very frequently
# 3     84.0             Sometimes               Never            Never
# 4    107.0                 Never               Never           Rarely
# ..     ...                   ...                 ...              ...
# 731  120.0       Very frequently              Rarely            Never
# 732  160.0                Rarely              Rarely            Never
# 733  120.0                Rarely           Sometimes        Sometimes
# 734  170.0       Very frequently               Never            Never
# 735   98.0             Sometimes              Rarely  Very frequently
#
#     Frequency [Folk] Frequency [Gospel] Frequency [Hip hop] Frequency [Jazz]  \
# 0              Never              Never           Sometimes            Never
# 1             Rarely          Sometimes              Rarely  Very frequently
# 2              Never              Never              Rarely           Rarely
# 3             Rarely          Sometimes               Never  Very frequently
# 4              Never             Rarely     Very frequently            Never
# ..               ...                ...                 ...              ...
# 731        Sometimes              Never           Sometimes           Rarely
# 732            Never              Never               Never           Rarely
# 733           Rarely             Rarely     Very frequently           Rarely
# 734            Never              Never               Never           Rarely
# 735        Sometimes             Rarely     Very frequently  Very frequently
#
#     Frequency [K pop] Frequency [Latin] Frequency [Lofi] Frequency [Metal]  \
# 0     Very frequently   Very frequently           Rarely             Never
# 1              Rarely         Sometimes           Rarely             Never
# 2     Very frequently             Never        Sometimes         Sometimes
# 3           Sometimes   Very frequently        Sometimes             Never
# 4     Very frequently         Sometimes        Sometimes             Never
# ..                ...               ...              ...               ...
# 731             Never         Sometimes           Rarely            Rarely
# 732             Never             Never           Rarely             Never
# 733            Rarely            Rarely        Sometimes            Rarely
# 734             Never             Never            Never             Never
# 735         Sometimes             Never           Rarely             Never
#
#      Frequency [Pop]  Frequency [R&B]  Frequency [Rap] Frequency [Rock]  \
# 0    Very frequently        Sometimes  Very frequently            Never
# 1          Sometimes        Sometimes           Rarely  Very frequently
# 2             Rarely            Never           Rarely           Rarely
# 3          Sometimes        Sometimes            Never            Never
# 4          Sometimes  Very frequently  Very frequently            Never
# ..               ...              ...              ...              ...
# 731  Very frequently            Never           Rarely  Very frequently
# 732  Very frequently            Never            Never        Sometimes
# 733        Sometimes        Sometimes        Sometimes           Rarely
# 734            Never            Never            Never            Never
# 735        Sometimes  Very frequently  Very frequently  Very frequently
#
#     Frequency [Video game music]  Anxiety  Depression  Insomnia  OCD  \
# 0                      Sometimes      3.0         0.0       1.0  0.0
# 1                         Rarely      7.0         2.0       2.0  1.0
# 2                Very frequently      7.0         7.0      10.0  2.0
# 3                          Never      9.0         7.0       3.0  3.0
# 4                         Rarely      7.0         2.0       5.0  9.0
# ..                           ...      ...         ...       ...  ...
# 731                        Never      7.0         6.0       0.0  9.0
# 732                    Sometimes      3.0         2.0       2.0  5.0
# 733                       Rarely      2.0         2.0       2.0  2.0
# 734                    Sometimes      2.0         3.0       2.0  1.0
# 735                       Rarely      2.0         2.0       2.0  5.0
#
#     Music effects    Permissions
# 0             NaN  I understand.
# 1             NaN  I understand.
# 2       No effect  I understand.
# 3         Improve  I understand.
# 4         Improve  I understand.
# ..            ...            ...
# 731       Improve  I understand.
# 732       Improve  I understand.
# 733       Improve  I understand.
# 734       Improve  I understand.
# 735       Improve  I understand.
#
# [736 rows x 32 columns]

# %%
#I have also decided to remove the 'instrumentalist' and 'composer' columns since the dataset info shows that these represent whether the responder plays an 
#instrument or composes music on their own, which is also irrelevant to the business questions and analysis questions being asked for this dataset
df2 = df.drop(['Instrumentalist', 'Composer'], axis=1)
df2.head()
# Out:
#             Timestamp   Age Primary streaming service  Hours per day  \
# 0  8/27/2022 19:29:02  18.0                   Spotify            3.0
# 1  8/27/2022 19:57:31  63.0                   Pandora            1.5
# 2  8/27/2022 21:28:18  18.0                   Spotify            4.0
# 3  8/27/2022 21:40:40  61.0             YouTube Music            2.5
# 4  8/27/2022 21:54:47  18.0                   Spotify            4.0
#
#   While working         Fav genre Exploratory Foreign languages    BPM  \
# 0           Yes             Latin         Yes               Yes  156.0
# 1           Yes              Rock         Yes                No  119.0
# 2            No  Video game music          No               Yes  132.0
# 3           Yes              Jazz         Yes               Yes   84.0
# 4           Yes               R&B         Yes                No  107.0
#
#   Frequency [Classical] Frequency [Country]  Frequency [EDM] Frequency [Folk]  \
# 0                Rarely               Never           Rarely            Never
# 1             Sometimes               Never            Never           Rarely
# 2                 Never               Never  Very frequently            Never
# 3             Sometimes               Never            Never           Rarely
# 4                 Never               Never           Rarely            Never
#
#   Frequency [Gospel] Frequency [Hip hop] Frequency [Jazz] Frequency [K pop]  \
# 0              Never           Sometimes            Never   Very frequently
# 1          Sometimes              Rarely  Very frequently            Rarely
# 2              Never              Rarely           Rarely   Very frequently
# 3          Sometimes               Never  Very frequently         Sometimes
# 4             Rarely     Very frequently            Never   Very frequently
#
#   Frequency [Latin] Frequency [Lofi] Frequency [Metal]  Frequency [Pop]  \
# 0   Very frequently           Rarely             Never  Very frequently
# 1         Sometimes           Rarely             Never        Sometimes
# 2             Never        Sometimes         Sometimes           Rarely
# 3   Very frequently        Sometimes             Never        Sometimes
# 4         Sometimes        Sometimes             Never        Sometimes
#
#    Frequency [R&B]  Frequency [Rap] Frequency [Rock]  \
# 0        Sometimes  Very frequently            Never
# 1        Sometimes           Rarely  Very frequently
# 2            Never           Rarely           Rarely
# 3        Sometimes            Never            Never
# 4  Very frequently  Very frequently            Never
#
#   Frequency [Video game music]  Anxiety  Depression  Insomnia  OCD  \
# 0                    Sometimes      3.0         0.0       1.0  0.0
# 1                       Rarely      7.0         2.0       2.0  1.0
# 2              Very frequently      7.0         7.0      10.0  2.0
# 3                        Never      9.0         7.0       3.0  3.0
# 4                       Rarely      7.0         2.0       5.0  9.0
#
#   Music effects    Permissions
# 0           NaN  I understand.
# 1           NaN  I understand.
# 2     No effect  I understand.
# 3       Improve  I understand.
# 4       Improve  I understand.

# %%
#here I am converting the cleaned data to a new csv file
df2.to_csv("mental_music_cleaned.csv")

# %%
#putting this code here to make sure that everything works and is viewable
df_cleaned = pd.read_csv("mental_music_cleaned.csv")
df_cleaned.head(11)
# Out:
#     Unnamed: 0           Timestamp   Age          Primary streaming service  \
# 0            0  8/27/2022 19:29:02  18.0                            Spotify
# 1            1  8/27/2022 19:57:31  63.0                            Pandora
# 2            2  8/27/2022 21:28:18  18.0                            Spotify
# 3            3  8/27/2022 21:40:40  61.0                      YouTube Music
# 4            4  8/27/2022 21:54:47  18.0                            Spotify
# 5            5  8/27/2022 21:56:50  18.0                            Spotify
# 6            6  8/27/2022 22:00:29  18.0                      YouTube Music
# 7            7  8/27/2022 22:18:59  21.0                            Spotify
# 8            8  8/27/2022 22:33:05  19.0                            Spotify
# 9            9  8/27/2022 22:44:03  18.0  I do not use a streaming service.
# 10          10  8/27/2022 22:51:15  18.0                            Spotify
#
#     Hours per day While working         Fav genre Exploratory  \
# 0             3.0           Yes             Latin         Yes
# 1             1.5           Yes              Rock         Yes
# 2             4.0            No  Video game music          No
# 3             2.5           Yes              Jazz         Yes
# 4             4.0           Yes               R&B         Yes
# 5             5.0           Yes              Jazz         Yes
# 6             3.0           Yes  Video game music         Yes
# 7             1.0           Yes             K pop         Yes
# 8             6.0           Yes              Rock          No
# 9             1.0           Yes               R&B         Yes
# 10            3.0           Yes           Country         Yes
#
#    Foreign languages    BPM Frequency [Classical] Frequency [Country]  \
# 0                Yes  156.0                Rarely               Never
# 1                 No  119.0             Sometimes               Never
# 2                Yes  132.0                 Never               Never
# 3                Yes   84.0             Sometimes               Never
# 4                 No  107.0                 Never               Never
# 5                Yes   86.0                Rarely           Sometimes
# 6                Yes   66.0             Sometimes               Never
# 7                Yes   95.0                 Never               Never
# 8                 No   94.0                 Never     Very frequently
# 9                Yes  155.0                Rarely              Rarely
# 10                No    NaN                 Never     Very frequently
#
#     Frequency [EDM] Frequency [Folk] Frequency [Gospel] Frequency [Hip hop]  \
# 0            Rarely            Never              Never           Sometimes
# 1             Never           Rarely          Sometimes              Rarely
# 2   Very frequently            Never              Never              Rarely
# 3             Never           Rarely          Sometimes               Never
# 4            Rarely            Never             Rarely     Very frequently
# 5             Never            Never              Never           Sometimes
# 6            Rarely        Sometimes             Rarely              Rarely
# 7            Rarely            Never              Never     Very frequently
# 8             Never        Sometimes              Never               Never
# 9            Rarely           Rarely          Sometimes              Rarely
# 10            Never            Never              Never               Never
#
#    Frequency [Jazz] Frequency [K pop] Frequency [Latin] Frequency [Lofi]  \
# 0             Never   Very frequently   Very frequently           Rarely
# 1   Very frequently            Rarely         Sometimes           Rarely
# 2            Rarely   Very frequently             Never        Sometimes
# 3   Very frequently         Sometimes   Very frequently        Sometimes
# 4             Never   Very frequently         Sometimes        Sometimes
# 5   Very frequently   Very frequently            Rarely  Very frequently
# 6         Sometimes             Never            Rarely           Rarely
# 7            Rarely   Very frequently             Never        Sometimes
# 8             Never             Never             Never            Never
# 9            Rarely             Never            Rarely           Rarely
# 10            Never             Never             Never            Never
#
#    Frequency [Metal]  Frequency [Pop]  Frequency [R&B]  Frequency [Rap]  \
# 0              Never  Very frequently        Sometimes  Very frequently
# 1              Never        Sometimes        Sometimes           Rarely
# 2          Sometimes           Rarely            Never           Rarely
# 3              Never        Sometimes        Sometimes            Never
# 4              Never        Sometimes  Very frequently  Very frequently
# 5             Rarely  Very frequently  Very frequently  Very frequently
# 6             Rarely           Rarely           Rarely            Never
# 7              Never        Sometimes        Sometimes           Rarely
# 8    Very frequently            Never            Never            Never
# 9              Never        Sometimes        Sometimes           Rarely
# 10             Never           Rarely           Rarely            Never
#
#    Frequency [Rock] Frequency [Video game music]  Anxiety  Depression  \
# 0             Never                    Sometimes      3.0         0.0
# 1   Very frequently                       Rarely      7.0         2.0
# 2            Rarely              Very frequently      7.0         7.0
# 3             Never                        Never      9.0         7.0
# 4             Never                       Rarely      7.0         2.0
# 5   Very frequently                        Never      8.0         8.0
# 6             Never                    Sometimes      4.0         8.0
# 7             Never                       Rarely      5.0         3.0
# 8   Very frequently                        Never      2.0         0.0
# 9         Sometimes                    Sometimes      2.0         2.0
# 10           Rarely                        Never      7.0         7.0
#
#     Insomnia  OCD Music effects    Permissions
# 0        1.0  0.0           NaN  I understand.
# 1        2.0  1.0           NaN  I understand.
# 2       10.0  2.0     No effect  I understand.
# 3        3.0  3.0       Improve  I understand.
# 4        5.0  9.0       Improve  I understand.
# 5        7.0  7.0       Improve  I understand.
# 6        6.0  0.0       Improve  I understand.
# 7        5.0  3.0       Improve  I understand.
# 8        0.0  0.0       Improve  I understand.
# 9        5.0  1.0       Improve  I understand.
# 10       4.0  7.0     No effect  I understand.

# %% [markdown]
# ## Inconsistent Data
#
# Check for inconsistent data and address any that arises. As always, use code comments to illustrate your thought process.

# %%
df['Fav genre'].hist(bins=35, figsize=(25, 10), color = ['purple'])
plt.xlabel('Most Popular Genres', fontsize=15)
plt.ylabel('Number of Users', fontsize=15)
df2.plot.bar()

#I wanted to run a bar chart here that I implemented from checkpoint 2 to see if there were any inconsistencies in the number of users putting their 
#music genre interests on the survey. it seems like rock music stands out above the rest, however this might prove to be a consistent theme when factoring in
#things like 'hours per day' where rock music has a few outliers showing that streams lasted 24 hours straight

#since a majority of this data seems to be non-mumerical, i may have to change some of the values to be on a numerical scale later
#I am going to wait until I get deeper into the vizualization phase on tableau to see if more data cleaning needs work
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Summarize Your Results
#
# Make note of your answers to the following questions.
#
# 1. **Did you find all four types of dirty data in your dataset?** I did find some data that needed to be removed to being irrelevant to analysis. I also found that some data might need to be converted to numerical values, however analyses will still be able to be completed for now
# 2. **Did the process of cleaning your data give you new insights into your dataset?**  yes, I found that there were actually many outliers present that could skew results a bit when looking at the entire column
# 3. **Is there anything you would like to make note of when it comes to manipulating the data and making visualizations?** I want to make note of the survey responses that are on ranges of 'never' to 'frequently' as these inputs might need to be converted to numerical values if errors are given at later stages of the project.
